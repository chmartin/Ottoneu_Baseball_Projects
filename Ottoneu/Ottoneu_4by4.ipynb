# %% [markdown]
# # Download GameType Averages

# %%
League_path = '/Users/cmartin/Fantasy_Baseball/Ottoneu_Baseball_Projects/Ottoneu'

# %%
export_date = 'Mar21_2026'

# %%
GameType = 1
GameName = 'Ottoneu_4x4'

# %%
url = f'https://ottoneu.fangraphs.com/averageValues?export=csv&gameType={GameType}'

# %%
import pandas as pd

# %%
Ottoneu_df = pd.read_csv(url)

# %%
Ottoneu_df.head()
# Out:
#                Name  OttoneuID  FG MajorLeagueID FG MinorLeagueID MLB Org  \
# 0     Shohei Ohtani      33600           19755.0              NaN     LAD
# 1       Aaron Judge      18312           15640.0         sa549847     NYY
# 2         Juan Soto      23717           20123.0         sa906282     NYM
# 3    Yordan Alvarez      23795           19556.0         sa943524     HOU
# 4  Ronald Acuña Jr.      23327           18401.0         sa877503     ATL
#
#   Position(s) Avg Salary Median Salary Min Salary Max Salary Last 10  Roster%
# 0     Util/SP     $77.96        $77.50        $64        $89  $61.40  100.000
# 1          OF     $72.00        $71.00        $60        $84  $56.20  100.000
# 2          OF     $68.92        $69.50        $59        $80  $68.90  100.000
# 3          OF     $53.00        $52.00        $45        $66  $53.90   95.833
# 4          OF     $51.88        $50.00        $38        $72  $48.00  100.000

# %%
import os
import errno
Write_Path = League_path+'/'+GameName
if not os.path.exists(Write_Path):
    os.makedirs(Write_Path)

# %%
Ottoneu_df.to_csv(f'{Write_Path}/{export_date}.csv')

# %%
def symlink_force(target, link_name):
    try:
        os.symlink(target, link_name)
    except OSError as e:
        if e.errno == errno.EEXIST:
            os.remove(link_name)
            os.symlink(target, link_name)
        else:
            raise e

# %%
latest_link_name = League_path+f'/Latest_{GameName}.csv'
symlink_force(f'{Write_Path}/{export_date}.csv',latest_link_name)
